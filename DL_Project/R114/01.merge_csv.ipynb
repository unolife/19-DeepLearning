# %%
import pandas as pd
s1 = pd.read_csv('./전국매매통합/서울통합본.csv')
# Out:
# C:\ProgramData\Anaconda3\envs\p36\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
s1
# Out:
#            도시  구시군   읍면동          단지명  전용면적(㎡) 거래금액(만원)  거래층      계약일  \
# 0       서울특별시  강남구  압구정동        구현대1차   196.21  450,000   13  2018.12
# 1       서울특별시  강남구   청담동      마크힐스2단지   202.58  450,000    5  2018.12
# 2       서울특별시  강남구  압구정동          신현대   139.83  320,000    7  2018.12
# 3       서울특별시  강남구   대치동     한보미도맨션1차   191.04  315,000    2  2018.12
# 4       서울특별시  강남구  압구정동        구현대7차   144.20  304,000   10  2018.12
# 5       서울특별시  강남구   수서동     강남더샵포레스트   165.43  300,000    8  2018.12
# 6       서울특별시  강남구   대치동     래미안대치팰리스    94.49  280,000   16  2018.12
# 7       서울특별시  강남구   대치동       동부센트레빌   145.83  279,000   20  2018.12
# 8       서울특별시  강남구   청담동  청담대우로얄카운티VI   191.59  250,000    6  2018.12
# 9       서울특별시  강남구   논현동        동양파라곤   160.33  240,000   14  2018.12
# 10      서울특별시  강남구   대치동     한보미도맨션2차   126.00  238,000    9  2018.12
# 11      서울특별시  강남구   대치동     한보미도맨션2차   137.00  238,000    9  2018.12
# ...

# %%
g1 = pd.read_csv('./전국매매통합/경기1(ㄱ-ㅅ).csv')
g2 = pd.read_csv('./전국매매통합/경기2.csv')
g3 = pd.read_csv('./전국매매통합/강원매매.csv')
g4 = pd.read_csv('./전국매매통합/경남매매.csv')
g5 = pd.read_csv('./전국매매통합/경북매매.csv')
g6 = pd.read_csv('./전국매매통합/광주매매.csv')
d1 = pd.read_csv('./전국매매통합/대구매매.csv')
d2 = pd.read_csv('./전국매매통합/대전매매.csv')
b1 = pd.read_csv('./전국매매통합/부산매매.csv')
s2 = pd.read_csv('./전국매매통합/세종매매.csv')
u1 = pd.read_csv('./전국매매통합/울산매매.csv')
i1 = pd.read_csv('./전국매매통합/인천매매.csv')
j1 = pd.read_csv('./전국매매통합/전남매매.csv')
j2 = pd.read_csv('./전국매매통합/전북매매.csv')
j3 = pd.read_csv('./전국매매통합/제주매매.csv')
c1 = pd.read_csv('./전국매매통합/충남매매.csv')
c2 = pd.read_csv('./전국매매통합/충북매매.csv')
# Out:
# C:\ProgramData\Anaconda3\envs\p36\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\envs\p36\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\envs\p36\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
total = pd.concat([s1, g1,g2,g3,g4,g5,g6,d1,d2,b1,s2,u1,i1,j1,j2,j3,c1,c2], axis=0)
total.head()
# Out:
#       도시  구시군   읍면동       단지명  전용면적(㎡) 거래금액(만원)   거래층      계약일  분양면적(㎡)  \
# 0  서울특별시  강남구  압구정동     구현대1차   196.21  450,000  13.0  2018.12   211.23
# 1  서울특별시  강남구   청담동   마크힐스2단지   202.58  450,000   5.0  2018.12   252.31
# 2  서울특별시  강남구  압구정동       신현대   139.83  320,000   7.0  2018.12   165.29
# 3  서울특별시  강남구   대치동  한보미도맨션1차   191.04  315,000   2.0  2018.12   219.22
# 4  서울특별시  강남구  압구정동     구현대7차   144.20  304,000  10.0  2018.12   158.68
#
#        입주일      분양일  분양가(만원)   총세대수 면적별세대수 3.3㎡당가(전용면적-만원) 3.3㎡당가(분양면적-만원)  \
# 0  1976.06      NaN      NaN    480    120           7,582           7,043
# 1  2010.07  2009.05  600,000     19      1           7,343           5,896
# 2  1982.04      NaN      NaN  1,924    168           7,565           6,400
# 3  1983.12      NaN    8,978  1,204     84           5,451           4,750
# 4  1979.05      NaN      NaN    560    168           6,969           6,333
#
#   3.3㎡당가(분양가-만원)
# 0            NaN
# 1          7,861
# 2            NaN
# ...

# %%
list1 = ["city","district", "dong", "apartment","m2","price","floor","contract_date", "pre_m2", "moving_date", "pre_date","pre_price", "num_people", "people_by_m2", "price_by_m2","price_by_pre_m2", "price_by_pre_price"]

# %%
total.columns = list1

# %%
total.tail()
# Out:
#           도시  구시군  읍면동   단지명  전용면적(㎡) 거래금액(만원)  거래층      계약일  분양면적(㎡)  \
# 129941  충청북도  제천시  청전동  주공1차    42.54    1,700  1.0  2018.11    42.98
# 129942  충청북도  보은군  마로면    조일    50.19    1,700  3.0  2018.09    58.94
# 129943  충청북도  보은군  마로면    조일    50.19    1,700  3.0  2018.10    58.94
# 129944  충청북도  제천시  청전동  주공1차    41.99    1,700  5.0  2018.10    42.98
# 129945  충청북도  제천시  청전동  주공1차    41.56    1,500  5.0  2018.07    42.98
#
#             입주일  분양일 분양가(만원) 총세대수 면적별세대수 3.3㎡당가(전용면적-만원) 3.3㎡당가(분양면적-만원)  \
# 129941  1980.11  NaN     NaN  640    250             132             131
# 129942  1985.11  NaN     NaN   40     40             112              95
# 129943  1985.11  NaN     NaN   40     40             112              95
# 129944  1980.11  NaN     NaN  640    100             134             131
# 129945  1980.11  NaN     NaN  640     50             119             115
#
#        3.3㎡당가(분양가-만원)
# 129941            NaN
# 129942            NaN
# 129943            NaN
# ...

# %%
total = total.reset_index(drop=True)

# %%
total.tail()
# Out:
#            도시  구시군  읍면동   단지명  전용면적(㎡) 거래금액(만원)  거래층      계약일  분양면적(㎡)  \
# 6174900  충청북도  제천시  청전동  주공1차    42.54    1,700  1.0  2018.11    42.98
# 6174901  충청북도  보은군  마로면    조일    50.19    1,700  3.0  2018.09    58.94
# 6174902  충청북도  보은군  마로면    조일    50.19    1,700  3.0  2018.10    58.94
# 6174903  충청북도  제천시  청전동  주공1차    41.99    1,700  5.0  2018.10    42.98
# 6174904  충청북도  제천시  청전동  주공1차    41.56    1,500  5.0  2018.07    42.98
#
#              입주일  분양일 분양가(만원) 총세대수 면적별세대수 3.3㎡당가(전용면적-만원) 3.3㎡당가(분양면적-만원)  \
# 6174900  1980.11  NaN     NaN  640    250             132             131
# 6174901  1985.11  NaN     NaN   40     40             112              95
# 6174902  1985.11  NaN     NaN   40     40             112              95
# 6174903  1980.11  NaN     NaN  640    100             134             131
# 6174904  1980.11  NaN     NaN  640     50             119             115
#
#         3.3㎡당가(분양가-만원)
# 6174900            NaN
# 6174901            NaN
# ...

# %%
total.to_csv("korea_apartment.csv", index=False)

# %%
ex = pd.read_csv("./korea_apartment.csv")
# Out:
# C:\ProgramData\Anaconda3\envs\p36\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (13,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ex.tail()
# Out:
#          city district dong apartment     m2  price  floor  contract_date  \
# 6174900  충청북도      제천시  청전동      주공1차  42.54  1,700    1.0        2018.11
# 6174901  충청북도      보은군  마로면        조일  50.19  1,700    3.0        2018.09
# 6174902  충청북도      보은군  마로면        조일  50.19  1,700    3.0        2018.10
# 6174903  충청북도      제천시  청전동      주공1차  41.99  1,700    5.0        2018.10
# 6174904  충청북도      제천시  청전동      주공1차  41.56  1,500    5.0        2018.07
#
#          pre_m2  moving_date  pre_date pre_price num_people people_by_m2  \
# 6174900   42.98      1980.11       NaN       NaN        640          250
# 6174901   58.94      1985.11       NaN       NaN         40           40
# 6174902   58.94      1985.11       NaN       NaN         40           40
# 6174903   42.98      1980.11       NaN       NaN        640          100
# 6174904   42.98      1980.11       NaN       NaN        640           50
#
#         price_by_m2 price_by_pre_m2 price_by_pre_price
# ...

# %%
# columns = s1.loc[0,:]
# s1 = s1.drop(0,0)
